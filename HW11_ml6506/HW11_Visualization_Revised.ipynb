# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from pandas import DataFrame
from matplotlib import pyplot as plt
import urllib.request
from urllib.request import urlretrieve as urlretrieve
import geopandas as gpd
import os
import json
import requests
import zipfile
import io
from io import StringIO
from fiona.crs import from_epsg
import shapely
from shapely.geometry import Point, LineString
import matplotlib.pylab as plt
try:
    import ipywidgets as widgets
    hasWidgets = True
except ImportError:
    hasWidgets = False

# %%
# Download the sybway station data
url = "https://data.cityofnewyork.us/api/geospatial/arq3-7z49?method=export&format=Shapefile"
urllib.request.urlretrieve(url, "subway.gz")
# Out:
# ('subway.gz', <http.client.HTTPMessage at 0x7fcf2af422e8>)

# %%
# !unzip -d $PUIDATA subway.gz
# Out:
# Archive:  subway.gz
#   inflating: /nfshome/ml6506/PUIdata/geo_export_0d676f84-4d9f-460d-b29a-7d26e12cd748.dbf
#   inflating: /nfshome/ml6506/PUIdata/geo_export_0d676f84-4d9f-460d-b29a-7d26e12cd748.shp
#   inflating: /nfshome/ml6506/PUIdata/geo_export_0d676f84-4d9f-460d-b29a-7d26e12cd748.shx
#   inflating: /nfshome/ml6506/PUIdata/geo_export_0d676f84-4d9f-460d-b29a-7d26e12cd748.prj

# %%
subway = gpd.GeoDataFrame.from_file(os.getenv("PUIDATA") + "/" + 
                                     "geo_export_3eab19af-2a60-4abe-a6d0-220af7b510d1.shp")

# %%
subway.head()
# Out:
#             line              name  \
# 0  4-6-6 Express          Astor Pl
# 1  4-6-6 Express          Canal St
# 2            1-2           50th St
# 3          2-3-4         Bergen St
# 4            3-4  Pennsylvania Ave
#
#                                                notes  objectid  \
# 0  4 nights, 6-all times, 6 Express-weekdays AM s...       1.0
# 1  4 nights, 6-all times, 6 Express-weekdays AM s...       2.0
# 2                              1-all times, 2-nights       3.0
# 3           4-nights, 3-all other times, 2-all times       4.0
# 4                        4-nights, 3-all other times       5.0
#
#                                  url  \
# 0  http://web.mta.info/nyct/service/
# 1  http://web.mta.info/nyct/service/
# 2  http://web.mta.info/nyct/service/
# 3  http://web.mta.info/nyct/service/
# 4  http://web.mta.info/nyct/service/
#
#                                        geometry
# 0  POINT (-73.99106999861966 40.73005400028978)
# 1  POINT (-74.00019299927328 40.71880300107709)
# 2  POINT (-73.98384899986625 40.76172799961419)
# 3  POINT (-73.97499915116808 40.68086213682956)
# 4  POINT (-73.89488591154061 40.66471445143568)

# %%
subway.crs
# Out:
# {'init': 'epsg:4326'}

# %%
# Download the NYC boundary data
url = "https://data.cityofnewyork.us/api/geospatial/cpf4-rkhq?method=export&format=Shapefile"
urllib.request.urlretrieve(url, "areafile.gz")
# Out:
# ('areafile.gz', <http.client.HTTPMessage at 0x7fcf2af60828>)

# %%
# !unzip -d $PUIDATA areafile.gz
# Out:
# Archive:  areafile.gz
#   inflating: /nfshome/ml6506/PUIdata/geo_export_121dd699-42c7-488c-a90b-661ba8da68bc.dbf
#   inflating: /nfshome/ml6506/PUIdata/geo_export_121dd699-42c7-488c-a90b-661ba8da68bc.shp
#   inflating: /nfshome/ml6506/PUIdata/geo_export_121dd699-42c7-488c-a90b-661ba8da68bc.shx
#   inflating: /nfshome/ml6506/PUIdata/geo_export_121dd699-42c7-488c-a90b-661ba8da68bc.prj

# %%
areashp = gpd.GeoDataFrame.from_file(os.getenv("PUIDATA") + "/" + 
                                     "geo_export_4e31d121-314b-4626-86ee-5857be3e57fb.shp")

# %%
areashp.head()
# Out:
#    boro_code  boro_name county_fip ntacode         ntaname    shape_area  \
# 0        3.0   Brooklyn        047    BK88    Borough Park  5.400502e+07
# 1        4.0     Queens        081    QN51     Murray Hill  5.248828e+07
# 2        4.0     Queens        081    QN27   East Elmhurst  1.972685e+07
# 3        4.0     Queens        081    QN07          Hollis  2.288777e+07
# 4        1.0  Manhattan        061    MN06  Manhattanville  1.064708e+07
#
#      shape_leng                                           geometry
# 0  39247.228028  POLYGON ((-73.97604935657381 40.63127590564677...
# 1  33266.904861  POLYGON ((-73.80379022888246 40.77561011179248...
# 2  19816.712318  POLYGON ((-73.86109724335759 40.7636644770869,...
# 3  20976.335574  POLYGON ((-73.75725671509139 40.71813860166257...
# 4  17040.685413  POLYGON ((-73.94607828674226 40.82126321606191...

# %%
areashp.crs
# Out:
# {'init': 'epsg:4326'}

# %%
import choroplethNYC as cp
cp.choroplethNYC(areashp, column=None, color="white", edgecolor="black", lw=2);

# %%
# spatial join two dataset
pp = gpd.sjoin(subway, areashp, how='inner', op='intersects', lsuffix='left', rsuffix='right')
pp.head()
# Out:
#               line                              name  \
# 0    4-6-6 Express                          Astor Pl
# 83         B-D-F-M  W 4th St - Washington Sq (Lower)
# 194            1-2      Christopher St - Sheridan Sq
# 205          A-C-E  W 4th St - Washington Sq (Upper)
# 383              L                Union Sq - 14th St
#
#                                                  notes  objectid  \
# 0    4 nights, 6-all times, 6 Express-weekdays AM s...       1.0
# 83            B,M-weekdays and evenings, D,F-all times      84.0
# 194                              1-all times, 2-nights     195.0
# 205              A,E-all times, C-all times exc nights     206.0
# 383                                        L-all times     384.0
#
#                                    url  \
# 0    http://web.mta.info/nyct/service/
# 83   http://web.mta.info/nyct/service/
# 194  http://web.mta.info/nyct/service/
# 205  http://web.mta.info/nyct/service/
# 383  http://web.mta.info/nyct/service/
#
#                                          geometry  index_right  boro_code  \
# 0    POINT (-73.99106999861966 40.73005400028978)          178        1.0
# 83   POINT (-74.00030814755975 40.73225449336788)          178        1.0
# 194  POINT (-74.00290599855235 40.73342200104225)          178        1.0
# 205  POINT (-74.00049500225435 40.73233799774325)          178        1.0
# 383  POINT (-73.99066976901818 40.73476331217923)          178        1.0
#
#      boro_name county_fip ntacode       ntaname    shape_area    shape_leng
# 0    Manhattan        061    MN23  West Village  2.500460e+07  29393.935726
# 83   Manhattan        061    MN23  West Village  2.500460e+07  29393.935726
# 194  Manhattan        061    MN23  West Village  2.500460e+07  29393.935726
# 205  Manhattan        061    MN23  West Village  2.500460e+07  29393.935726
# 383  Manhattan        061    MN23  West Village  2.500460e+07  29393.935726

# %%
# spatial join two dataset
pp2 = gpd.sjoin(areashp, subway, how='inner', op='intersects', lsuffix='left', rsuffix='right')
pp2.head()
# Out:
#    boro_code  boro_name county_fip ntacode         ntaname    shape_area  \
# 0        3.0   Brooklyn        047    BK88    Borough Park  5.400502e+07
# 0        3.0   Brooklyn        047    BK88    Borough Park  5.400502e+07
# 0        3.0   Brooklyn        047    BK88    Borough Park  5.400502e+07
# 0        3.0   Brooklyn        047    BK88    Borough Park  5.400502e+07
# 4        1.0  Manhattan        061    MN06  Manhattanville  1.064708e+07
#
#      shape_leng                                           geometry  \
# 0  39247.228028  POLYGON ((-73.97604935657381 40.63127590564677...
# 0  39247.228028  POLYGON ((-73.97604935657381 40.63127590564677...
# 0  39247.228028  POLYGON ((-73.97604935657381 40.63127590564677...
# 0  39247.228028  POLYGON ((-73.97604935657381 40.63127590564677...
# 4  17040.685413  POLYGON ((-73.94607828674226 40.82126321606191...
#
#    index_right line                     name        notes  objectid  \
# 0          337    F                    Ave N  F-all times     338.0
# 0          311    N         Ft Hamilton Pkwy  N-all times     312.0
# 0           61    D                  55th St  D-all times      62.0
# 0          310    D                  50th St  D-all times     311.0
# 4          171    1  137th St - City College  1-all times     172.0
#
#                                  url
# 0  http://web.mta.info/nyct/service/
# 0  http://web.mta.info/nyct/service/
# 0  http://web.mta.info/nyct/service/
# 0  http://web.mta.info/nyct/service/
# 4  http://web.mta.info/nyct/service/

# %%
pp2.columns
# Out:
# Index(['boro_code', 'boro_name', 'county_fip', 'ntacode', 'ntaname',
#        'shape_area', 'shape_leng', 'geometry', 'index_right', 'line', 'name',
#        'notes', 'objectid', 'url'],
#       dtype='object')

# %%
pp2.head()
# Out:
#    boro_code  boro_name county_fip ntacode         ntaname    shape_area  \
# 0        3.0   Brooklyn        047    BK88    Borough Park  5.400502e+07
# 0        3.0   Brooklyn        047    BK88    Borough Park  5.400502e+07
# 0        3.0   Brooklyn        047    BK88    Borough Park  5.400502e+07
# 0        3.0   Brooklyn        047    BK88    Borough Park  5.400502e+07
# 4        1.0  Manhattan        061    MN06  Manhattanville  1.064708e+07
#
#      shape_leng                                           geometry  \
# 0  39247.228028  POLYGON ((-73.97604935657381 40.63127590564677...
# 0  39247.228028  POLYGON ((-73.97604935657381 40.63127590564677...
# 0  39247.228028  POLYGON ((-73.97604935657381 40.63127590564677...
# 0  39247.228028  POLYGON ((-73.97604935657381 40.63127590564677...
# 4  17040.685413  POLYGON ((-73.94607828674226 40.82126321606191...
#
#    index_right line                     name        notes  objectid  \
# 0          337    F                    Ave N  F-all times     338.0
# 0          311    N         Ft Hamilton Pkwy  N-all times     312.0
# 0           61    D                  55th St  D-all times      62.0
# 0          310    D                  50th St  D-all times     311.0
# 4          171    1  137th St - City College  1-all times     172.0
#
#                                  url
# 0  http://web.mta.info/nyct/service/
# 0  http://web.mta.info/nyct/service/
# 0  http://web.mta.info/nyct/service/
# 0  http://web.mta.info/nyct/service/
# 4  http://web.mta.info/nyct/service/

# %%
ppgb = pp2[['ntaname','name']].groupby("ntaname").count()

# %%
ppgbRi = ppgb.reset_index()

# %%
ppgbRi
# Out:
#                                                ntaname  name
# 0                                              Airport     1
# 1                              Allerton-Pelham Gardens     2
# 2                                              Astoria     5
# 3                    Battery Park City-Lower Manhattan    14
# 4                                            Bay Ridge     4
# 5                                              Bedford     4
# 6                           Bedford Park-Fordham North     4
# 7                                     Bensonhurst East     4
# 8                                     Bensonhurst West     9
# 9                                         Borough Park     4
# 10   Breezy Point-Belle Harbor-Rockaway Park-Broad ...     4
# 11                             Briarwood-Jamaica Hills     1
# 12                                      Brighton Beach     2
# 13                                           Bronxdale     2
# 14                        Brooklyn Heights-Cobble Hill     3
# 15                                         Brownsville     7
# 16                                      Bushwick North     7
# 17                                      Bushwick South     8
# 18                                            Canarsie     1
# 19            Carroll Gardens-Columbia Street-Red Hook     1
# 20                   Central Harlem North-Polo Grounds     5
# 21                                Central Harlem South     6
# 22                                           Chinatown     5
# 23                                             Clinton     1
# 24                                        Clinton Hill     4
# 25                                          Co-op City     1
# 26                                   Crotona Park East     1
# 27                                 Crown Heights North     8
# 28                                 Crown Heights South     2
# 29                             Cypress Hills-City Line     4
# ..                                                 ...   ...
# 95                                  Soundview-Bruckner     3
# 96                                    South Ozone Park     4
# 97                          Spuyten Duyvil-Kingsbridge     3
# 98                                            Steinway     1
# 99                                  Stuyvesant Heights     1
# 100                                   Sunset Park East     3
# 101                                   Sunset Park West     5
# 102                            Turtle Bay-East Midtown     3
# 103                  University Heights-Morris Heights     2
# 104                      Upper East Side-Carnegie Hill     7
# 105                                    Upper West Side     4
# 106                              Van Cortlandt Village     2
# 107            Van Nest-Morris Park-Westchester Square     1
# 108                           Washington Heights North     6
# 109                           Washington Heights South     5
# 110                                      West Brighton     2
# 111                                     West Concourse     5
# 112                             West Farms-Bronx River     1
# 113                                       West Village    10
# 114                              Westchester-Unionport     2
# 115                           Williamsbridge-Olinville     4
# 116                                       Williamsburg     2
# 117                                    Windsor Terrace     2
# 118                                          Woodhaven     3
# 119                                 Woodlawn-Wakefield     2
# 120                                           Woodside     4
# 121                                          Yorkville     1
# 122                         park-cemetery-etc-Brooklyn     2
# 123                        park-cemetery-etc-Manhattan     6
# 124                           park-cemetery-etc-Queens     1
#
# [125 rows x 2 columns]

# %%
pp3 = pd.merge(pp2[['ntaname','geometry']], ppgbRi, on='ntaname', how = 'left')

# %%
# I changed the scheme into " Quantiles" , which could better show the difference between areas. 
# "Quantiles" is much better than 'Equal_interval'
f, ax = plt.subplots(figsize=(10,10))
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
pp3.plot(column='name',cmap='viridis',alpha=1,linewidth=0.1,ax=ax, scheme="Quantiles", legend=True, k=7)
plt.title("Subway Station Density", fontsize=20);

# %%
# This is what my classmate suggested me to do, I used choroplethNYC and "continuous", the map seems very dark and not significnt
# In this case I
import choroplethNYC as cp
cp.choroplethNYC(pp3, "name",  kind='continuous', cmap="viridis")
# Out:
# (<matplotlib.figure.Figure at 0x7fcf51f692b0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fcf0ec579b0>,
#  <matplotlib.colorbar.Colorbar at 0x7fcf0dcdddd8>)

# %%
# The number of subway stations in each district
pp[['boro_name','name']].groupby("boro_name").count()
# Out:
#            name
# boro_name
# Bronx        70
# Brooklyn    169
# Manhattan   152
# Queens       82
